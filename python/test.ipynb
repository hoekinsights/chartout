# %%
import chartout

# %%
chart = chartout.altair_comet()
chart
# Out:
# alt.Chart(...)

# %%
store = chartout.Store(chart)
store
# Out:
# Store(active_item={'id': 'canvas_10x10', 'name': 'Canvas', 'textures': [{'id': 'canvas_10x10_texture', 'conten…

# %%
store.cart
# Out:
# [{'name': 'Canvas (10″x10″)',
#   'id': 'canvas_10x10',
#   'cartItemId': 'canvas_10x10_1753826870751',
#   'textures': [{'id': 'canvas_10x10_texture',
#     'type': 'image_stream',
#     'user_position': {'dx': 0,
#      'dy': 0,
#      'scale': 1,
#      'alignment': {'horizontal': 'center', 'vertical': 'middle'}},
#     'print_size': {'width': 3900, 'height': 3900, 'dpi': 300},
#     'print_position': {'width': 3900,
#      'height': 3207.175246732462,
#      'x': 0,
#      'y': 346.4123766337691},
#     'content': <memory at 0x1041c9900>}],
#   'quantity': 1,
#   'price': 15.35,
#   'variant_id': 19296,
#   'product_id': 3}]

# %%
#store.active_item

# %%
type(store.init_viz)

# %%
from IPython.display import Image as IPythonImage
texture_data = store.active_texture['texture']
IPythonImage(texture_data, width=300)

# %%
## << the remaining cells can be ignored >>

# %%
cart = chartout.Cart()

# %%
cart.add(chart)

# %%
chartout.CartItem(id='1', name='2', textures=[], quantity=1)

# %%
{
    'id': 'my_mousepad_id', 
    'textures': [{
        'id': 'my_mousepad_texture', 
        'content': chart
        }]
}

# %%
#store.active_item

# %%
store.cart

# %%
# cart = store.cart
# cart.append(cart[0])

# %%
store.cart

# %%
#store.active_item

# %%
store.init_item

# %%
#store.active_texture

# %%
    cart_item_data: CartItem = {
        "name": "Mug",
        "code": "403-11oz-color-mug",
        "image": "base64string",
        "quantity": 2,
        "position": {
            "width": 10,
            "height": 20,
            "top": 5,
            "left": 5
        },
        "texture": "smooth"
    }

# %%
item = {"name":"foo", "code": "bah", "image":"dis", "quantity":1}
cart = chartout.Cart()
cart.add(item)
cart

# %%
my_product = "403-11oz-color-mug"
my_position = chartout.Position({'left':167, 'top': 671 ,'width':335, 'height':670})
my_texture = chartout.chart_to_texture(chart, product=my_product, position=my_position)
Image(my_texture, width=300)

# %%
store = chartout.Store()
store

# %%
print(f"active: {store.active}\n cart: {store.cart}")

# %%
cart = store.cart
cart.append(cart[0])

# %%
print(f"active: {store.active}\n cart: {store.cart}")
